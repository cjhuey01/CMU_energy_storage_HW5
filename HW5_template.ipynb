# %%
import pybamm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from parameters.NMC_graphite_parameters import get_parameter_values

parameter_values = get_parameter_values()
parameter_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from parameters.NMC_graphite_parameters import get_parameter_values
# ----> 3 parameter_values = get_parameter_values()
#       4 parameter_values
#
# File c:\Users\hueyf\UMich\CMU_energy_storage_HW5\parameters\NMC_graphite_parameters.py:144, in get_parameter_values()
#     143 def get_parameter_values():
# --> 144     return ParameterValues(
#     145         {
#     146             "1 + dlnf/dlnc": 1.0,
#     147             "Ambient temperature [K]": 298.15,
#     148             "Cation transference number": 0.2594,
#     149             "Current function [A]": 5.0,
#     150             "Electrode height [m]": 0.065,
#     151             "Electrode width [m]": 1.58,
#     152             "Electrolyte conductivity [S.m-1]": electrolyte_conductivity_Nyman2008,
#     153             "Electrolyte diffusivity [m2.s-1]": electrolyte_diffusivity_Nyman2008,
#     154             "Initial concentration in electrolyte [mol.m-3]": 1000.0,
#     155             "Initial concentration in negative electrode [mol.m-3]": 30170.0,
#     156             "Initial concentration in positive electrode [mol.m-3]": 16653.0,
#     157             "Initial temperature [K]": 298.15,
#     158             "Lower voltage cut-off [V]": 2.5,
#     159             "Maximum concentration in negative electrode [mol.m-3]": 33133.0,
#     160             "Maximum concentration in positive electrode [mol.m-3]": 63104.0,
#     161             "Negative electrode Bruggeman coefficient (electrode)": 1.5,
#     162             "Negative electrode Bruggeman coefficient (electrolyte)": 1.5,
#     163             "Negative electrode OCP entropic change [V.K-1]": 0.0,
#     164             "Negative electrode active material volume fraction": 0.75,
#     165             "Negative electrode conductivity [S.m-1]": 215.0,
#     166             "Negative electrode diffusivity [m2.s-1]": 3.3e-14,
#     167             "Negative electrode electrons in reaction": 1.0,
#     168             "Negative electrode exchange-current density [A.m-2]": graphite_LGM50_electrolyte_exchange_current_density_Chen2020,
#     169             "Negative electrode porosity": 0.25,
#     170             "Negative electrode thickness [m]": 8.52e-05,
#     171             "Negative particle radius [m]": 5.86e-06,
#     172             "Nominal cell capacity [A.h]": 5.0,
#     173             "Number of cells connected in series to make a battery": 1.0,
#     174             "Number of electrodes connected in parallel to make a cell": 1.0,
#     175             "Positive electrode Bruggeman coefficient (electrode)": 1.5,
#     176             "Positive electrode Bruggeman coefficient (electrolyte)": 1.5,
#     177             "Positive electrode OCP entropic change [V.K-1]": 0.0,
#     178             "Positive electrode active material volume fraction": 0.665,
#     179             "Positive electrode conductivity [S.m-1]": 0.18,
#     180             "Positive electrode diffusivity [m2.s-1]": 4e-15,
#     181             "Positive electrode electrons in reaction": 1.0,
#     182             "Positive electrode exchange-current density [A.m-2]": nmc_LGM50_electrolyte_exchange_current_density_Chen2020,
#     183             "Positive electrode porosity": 0.335,
#     184             "Positive electrode thickness [m]": 7.56e-05,
#     185             "Positive particle radius [m]": 5.22e-06,
#     186             "Reference temperature [K]": 298.15,
#     187             "Separator Bruggeman coefficient (electrolyte)": 1.5,
#     188             "Separator porosity": 0.47,
#     189             "Separator thickness [m]": 1.2e-05,
#     190             "Typical current [A]": 5.0,
#     191             "Typical electrolyte concentration [mol.m-3]": 1000.0,
#     192             "Upper voltage cut-off [V]": 4.2,
#     193         }
#     194     )
#
# File c:\Users\hueyf\UMich\CMU_energy_storage_HW5\.venv\Lib\site-packages\pybamm\parameters\parameter_values.py:60, in ParameterValues.__init__(self, values, chemistry)
#      57 if isinstance(values, (dict, ParameterValues)):
#      58     # remove the "chemistry" key if it exists
#      59     values.pop("chemistry", None)
# ---> 60     self.update(values, check_already_exists=False)
#      61 else:
#      62     # Check if values is a named parameter set
#      63     if isinstance(values, str) and values in pybamm.parameter_sets.keys():
#
# File c:\Users\hueyf\UMich\CMU_energy_storage_HW5\.venv\Lib\site-packages\pybamm\parameters\parameter_values.py:236, in ParameterValues.update(self, values, check_conflict, check_already_exists, path)
#     234     values = values._dict_items
#     235 # check parameter values
# --> 236 values = self.check_parameter_values(values)
#     237 # update
#     238 for name, value in values.items():
#     239     # check for conflicts
#
# File c:\Users\hueyf\UMich\CMU_energy_storage_HW5\.venv\Lib\site-packages\pybamm\parameters\parameter_values.py:406, in ParameterValues.check_parameter_values(values)
#     404 # specific check for renamed parameter "1 + dlnf/dlnc"
#     405 if "1 + dlnf/dlnc" in param:
# --> 406     raise ValueError(
#     407         f"parameter '{param}' has been renamed to " "'Thermodynamic factor'"
#     408     )
#     409 if "electrode diffusivity" in param:
#     410     new_param = param.replace("electrode", "particle")
#
# ValueError: parameter '1 + dlnf/dlnc' has been renamed to 'Thermodynamic factor'

# %%
filenames = ["Lilium_Jet", "KH_Heaviside", "Joby_5seater", "Beta_Alia", "Archer_Maker"]
filename = filenames[0]
df = pd.read_csv("powerprofiles/" + filename + ".csv")
df
# Out:
#                  Segment        Times      PowerkW   EnergykWh         Rangem  \
# 0          TakeOff start     1.000000  2821.771187    0.000000       0.000000
# 1            TakeOff end    16.000000  2819.739842   11.753148       0.000000
# 2     TransitionUp start    17.000000  3990.587083   11.753148       0.000000
# 3       TransitionUp end    38.200000   410.418988   24.711666       0.000000
# 4            Climb start    39.200000   440.567515   24.711666       0.000000
# 5              Climb end   491.472727   465.417254   81.621694   24231.597855
# 6           Cruise start   492.472727   143.584466   81.621694   24231.597855
# 7             Cruise end  4175.706992   143.584466  228.525923  281831.597855
# 8          Descent start  4176.706992  -105.024413  228.525923  281831.597855
# 9            Descent end  4628.979719  -129.874152  213.770615  281831.597855
# 10  TransitionDown start  4629.979719  -160.022679  213.770615  281831.597855
# 11    TransitionDown end  4651.179719  3990.587083  225.049499  281831.597855
# 12         Landing start  4652.179719  2821.771187  225.049499  281831.597855
# 13           Landing end  4697.634264  2819.739842  260.665099  281831.597855
#
#     Altitudem  Airspeedmps  TemperatureK  SpeedOfSoundmps     PressurePa  \
# 0           0     0.000000      288.1500       340.294124  101325.000000
# 1          15     0.000000      288.0525       340.236548  101144.932646
# 2          15     0.000000      288.0525       340.236548  101144.932646
# 3          15    45.813347      288.0525       340.236548  101144.932646
# 4          15    49.229645      288.0525       340.236548  101144.932646
# 5        3000    57.104573      268.6500       328.578060   70108.547184
# 6        3000    69.938533      268.6500       328.578060   70108.547184
# 7        3000    69.938533      268.6500       328.578060   70108.547184
# 8        3000    57.104573      268.6500       328.578060   70108.547184
# 9          15    49.229645      288.0525       340.236548  101144.932646
# 10         15    45.813347      288.0525       340.236548  101144.932646
# 11         15     0.000000      288.0525       340.236548  101144.932646
# 12         15     0.000000      288.0525       340.236548  101144.932646
# 13          0     0.000000      288.1500       340.294124  101325.000000
#
#     Densitykgpm3
# 0       1.225000
# 1       1.223237
# 2       1.223237
# 3       1.223237
# 4       1.223237
# 5       0.909122
# 6       0.909122
# 7       0.909122
# 8       0.909122
# 9       1.223237
# 10      1.223237
# 11      1.223237
# 12      1.223237
# 13      1.225000
